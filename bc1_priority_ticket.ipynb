# %%
CI_Cat - Application- 32,900[71%], Subapplication- 7,782[17%], Computer- 3,643[8%] are the top 3 categories in the received tickets.

CI_Subcat - Server Based Application- 18,811[40%], Web Based Application- 15,311[33%], Desktop Application- 3,876[8%] are the top 3 Sub-Categories in the received tickets.

Status - most of the tickets status are Closed- 46,597[99%] ,and only 1% of the tickets are Work in progress- 9[1%].

Impact -Impact(1) with lowest tickets of only 3[1%], Impact(4) with highest tickets of 22556[48%].

Urgency - Urgency(1) with lowest tickets of only 6[1%], Urgency(4) with highest tickets of 22586[49%].

Priority - Priority(1) with lowest tickets of only 3[1%], and Priority(4) with highest tickets of 22,717[50%].

Alert_Status - All the tickets Alert Status are closed- 46,606[100%].

Category - the highest Category is incident with tickets of 37,748[81%] and lowest being request for change with only 1 ticket.

Closure_Code - the top 3 Closure_Code for the tickets are Other-16,470[36%], Software- 13,027[28%], User error- 3,554[8%].

# %%
## Importing the libraries
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_csv('project_itsm.csv',index_col=0)

# %%
pd.set_option('display.max_columns',None)

# %%
pd.set_option('display.max_rows',None)

# %%
data.isnull().sum()
# Out:
# CI_Name                           0
# CI_Cat                          111
# CI_Subcat                       111
# WBS                               0
# Incident_ID                       0
# Status                            0
# Impact                            0
# Urgency                           0
# Priority                       1380
# number_cnt                        0
# Category                          0
# KB_number                         0
# Alert_Status                      0
# No_of_Reassignments               1
# Open_Time                         0
# Reopen_Time                   44322
# Resolved_Time                  1780
# Close_Time                        0
# Handle_Time_hrs                   1
# Closure_Code                    460
# No_of_Related_Interactions      114
# Related_Interaction               0
# No_of_Related_Incidents       45384
# No_of_Related_Changes         46046
# Related_Change                46046
# dtype: int64

# %%
data.describe()
# Out:
#            Priority    number_cnt  No_of_Reassignments  \
# count  45226.000000  46606.000000         46605.000000
# mean       4.215805      0.499658             1.131831
# std        0.705624      0.288634             2.269774
# min        1.000000      0.000023             0.000000
# 25%        4.000000      0.248213             0.000000
# 50%        4.000000      0.500269             0.000000
# 75%        5.000000      0.749094             2.000000
# max        5.000000      0.999997            46.000000
#
#        No_of_Related_Interactions  No_of_Related_Incidents  \
# count                46492.000000              1222.000000
# mean                     1.149897                 1.669394
# std                      2.556338                 3.339687
# min                      1.000000                 1.000000
# 25%                      1.000000                 1.000000
# 50%                      1.000000                 1.000000
# ...

# %%
sns.boxplot(data["No_of_Related_Incidents"])
# Out:
# <AxesSubplot:xlabel='No_of_Related_Incidents'>

# %%
data[(data["No_of_Related_Incidents"] >= 50)]
# Out:
#          CI_Name       CI_Cat                 CI_Subcat        WBS  \
# 11040  SBA000773  application  Server Based Application  WBS000285
# 40314  SBA000773  application  Server Based Application  WBS000285
#
#       Incident_ID  Status Impact Urgency  Priority  number_cnt  Category  \
# 11040   IM0011212  Closed      2       2       2.0    0.176905  incident
# 40314   IM0040652  Closed      2       2       2.0    0.097650  incident
#
#        KB_number Alert_Status  No_of_Reassignments         Open_Time  \
# 11040  KM0000926       closed                  0.0  06-11-2013 07:55
# 40314  KM0000036       closed                  0.0  02-03-2014 05:33
#
#       Reopen_Time     Resolved_Time        Close_Time Handle_Time_hrs  \
# 11040         NaN  06-11-2013 10:46  06-11-2013 10:46  2,84,61,11,111
# 40314         NaN  02-03-2014 10:12  02-03-2014 10:12  4,65,05,55,556
#
#       Closure_Code  No_of_Related_Interactions Related_Interaction  \
# ...

# %%
data.drop(data[(data['No_of_Related_Incidents'] >= 50)].index, inplace=True)

# %%
sns.boxplot(data["No_of_Related_Interactions"])
# Out:
# <AxesSubplot:xlabel='No_of_Related_Interactions'>

# %%
data[(data["No_of_Related_Interactions"] >= 100)]
# Out:
#          CI_Name       CI_Cat                 CI_Subcat        WBS  \
# 167    CBA000014  application  Client Based Application  WBS000073
# 585    DTA000616  application       Desktop Application  WBS000092
# 30897  WBA000060  application     Web Based Application  WBS000073
#
#       Incident_ID  Status Impact Urgency  Priority  number_cnt  Category  \
# 167     IM0000220  Closed      4       3       3.0    0.407017  incident
# 585     IM0000674  Closed      4       4       4.0    0.819152  incident
# 30897   IM0031184  Closed      4       4       4.0    0.049780  incident
#
#        KB_number Alert_Status  No_of_Reassignments         Open_Time  \
# 167    KM0001692       closed                  3.0  16-07-2013 15:43
# 585    KM0001526       closed                  1.0  24-09-2013 09:26
# 30897  KM0000825       closed                  0.0  27-01-2014 09:10
#
#             Reopen_Time     Resolved_Time        Close_Time Handle_Time_hrs  \
# ...

# %%
data.drop(data[(data['No_of_Related_Interactions'] >= 100)].index, inplace=True)

# %%
data.describe()
# Out:
#            Priority    number_cnt  No_of_Reassignments  \
# count  45221.000000  46601.000000         46600.000000
# mean       4.215939      0.499679             1.131867
# std        0.705484      0.288627             2.269861
# min        1.000000      0.000023             0.000000
# 25%        4.000000      0.248344             0.000000
# 50%        4.000000      0.500299             0.000000
# 75%        5.000000      0.749094             2.000000
# max        5.000000      0.999997            46.000000
#
#        No_of_Related_Interactions  No_of_Related_Incidents  \
# count                46487.000000              1219.000000
# mean                     1.133285                 1.575882
# std                      1.242905                 2.415694
# min                      1.000000                 1.000000
# 25%                      1.000000                 1.000000
# 50%                      1.000000                 1.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46601 entries, 0 to 46605
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   CI_Name                     46601 non-null  object
#  1   CI_Cat                      46490 non-null  object
#  2   CI_Subcat                   46490 non-null  object
#  3   WBS                         46601 non-null  object
#  4   Incident_ID                 46601 non-null  object
#  5   Status                      46601 non-null  object
#  6   Impact                      46601 non-null  object
#  7   Urgency                     46601 non-null  object
#  8   Priority                    45221 non-null  float64
#  9   number_cnt                  46601 non-null  float64
#  10  Category                    46601 non-null  object
#  11  KB_number                   46601 non-null  object
#  12  Alert_Status                46601 non-null  object
# ...

# %%
data.isnull().sum()
# Out:
# CI_Name                           0
# CI_Cat                          111
# CI_Subcat                       111
# WBS                               0
# Incident_ID                       0
# Status                            0
# Impact                            0
# Urgency                           0
# Priority                       1380
# number_cnt                        0
# Category                          0
# KB_number                         0
# Alert_Status                      0
# No_of_Reassignments               1
# Open_Time                         0
# Reopen_Time                   44318
# Resolved_Time                  1780
# Close_Time                        0
# Handle_Time_hrs                   1
# Closure_Code                    460
# No_of_Related_Interactions      114
# Related_Interaction               0
# No_of_Related_Incidents       45382
# No_of_Related_Changes         46041
# Related_Change                46041
# dtype: int64

# %%
data.CI_Cat.replace(np.nan,'application',inplace=True)

# %%
data.CI_Subcat.replace(np.nan,'Server Based Application',inplace=True)

# %%
data.Urgency.replace(['5 - Very Low'],'6',inplace=True)

# %%
data[(data["Urgency"] == '6')]
# Out:
#          CI_Name       CI_Cat                 CI_Subcat        WBS  \
# 38305  SBA000743  application  Server Based Application  WBS000076
#
#       Incident_ID  Status Impact Urgency  Priority  number_cnt  \
# 38305   IM0038625  Closed      5       6       5.0    0.229756
#
#                       Category  KB_number Alert_Status  No_of_Reassignments  \
# 38305  request for information  KM0001519       closed                  0.0
#
#               Open_Time Reopen_Time     Resolved_Time        Close_Time  \
# 38305  20-02-2014 15:52         NaN  20-02-2014 15:57  20-02-2014 15:57
#
#       Handle_Time_hrs                  Closure_Code  \
# 38305     0,089166667  No error - works as designed
#
#        No_of_Related_Interactions Related_Interaction  \
# 38305                         1.0           SD0117519
#
#        No_of_Related_Incidents  No_of_Related_Changes Related_Change
# 38305                      NaN                    NaN            NaN

# %%
data.drop(data[(data['Urgency'] == '6')].index, inplace=True)

# %%
data['Urgency']=data['Urgency'].astype('int')

# %%
data.Urgency.value_counts()
# Out:
# 4    22586
# 5    16779
# 3     6535
# 2      694
# 1        6
# Name: Urgency, dtype: int64

# %%
data.Impact.replace(['NS'],'3',inplace=True)

# %%
data['Impact']=data['Impact'].astype('int')

# %%
data.Impact.mean()
# Out:
# 4.1874892703862665

# %%
data.Impact.value_counts()
# Out:
# 4    22553
# 5    16740
# 3     6614
# 2      690
# 1        3
# Name: Impact, dtype: int64

# %%
data.Priority.mean()
# Out:
# 4.215922158337019

# %%
data.Priority.replace(np.nan,3,inplace=True)

# %%
data['Priority']=data['Priority'].astype('int')

# %%
data.Priority.value_counts()
# Out:
# 4    22715
# 5    16485
# 3     6702
# 2      695
# 1        3
# Name: Priority, dtype: int64

# %%
data['Open_Time']= pd.to_datetime(data['Open_Time'], infer_datetime_format=True)
data['Resolved_Time']= pd.to_datetime(data['Resolved_Time'], infer_datetime_format=True)
data['Reopen_Time']= pd.to_datetime(data['Reopen_Time'], infer_datetime_format=True)
data['Close_Time']= pd.to_datetime(data['Close_Time'], infer_datetime_format=True)

# %%
data['Handle_Time_hrs'] = data['Handle_Time_hrs'].str.replace(',',':')

# %%
data.No_of_Reassignments.value_counts()
# Out:
# 0.0     27464
# 1.0      7267
# 2.0      5378
# 3.0      2190
# 4.0      1606
# 5.0       721
# 6.0       622
# 7.0       329
# 8.0       246
# 9.0       170
# 10.0      146
# 11.0      101
# 13.0       61
# 12.0       58
# 14.0       47
# 15.0       43
# 17.0       27
# 16.0       25
# 18.0       14
# 21.0       11
# 25.0       10
# 22.0       10
# 19.0       10
# 20.0        7
# 26.0        7
# 23.0        5
# 24.0        3
# 32.0        3
# 30.0        3
# 33.0        3
# 27.0        2
# 42.0        1
# 34.0        1
# 46.0        1
# 36.0        1
# 31.0        1
# 37.0        1
# 39.0        1
# 45.0        1
# 38.0        1
# 29.0        1
# Name: No_of_Reassignments, dtype: int64

# %%
data.No_of_Reassignments.mean()
# Out:
# 1.131891242301337

# %%
data.No_of_Reassignments.replace(np.nan,1,inplace=True)

# %%
data.No_of_Related_Interactions.value_counts()
# Out:
# 1.0     43055
# 2.0      2736
# 3.0       429
# 4.0       124
# 5.0        30
# 6.0        16
# 7.0        12
# 12.0        6
# 8.0         6
# 20.0        5
# 9.0         5
# 13.0        4
# 42.0        3
# 22.0        3
# 10.0        3
# 15.0        3
# 19.0        3
# 14.0        2
# 23.0        2
# 28.0        2
# 18.0        2
# 17.0        2
# 45.0        2
# 11.0        2
# 16.0        2
# 39.0        2
# 33.0        2
# 44.0        2
# 26.0        2
# 29.0        2
# 34.0        2
# 21.0        1
# 41.0        1
# 24.0        1
# 88.0        1
# 57.0        1
# 54.0        1
# 40.0        1
# 74.0        1
# 31.0        1
# 55.0        1
# 37.0        1
# 27.0        1
# 43.0        1
# 30.0        1
# 25.0        1
# Name: No_of_Related_Interactions, dtype: int64

# %%
data.No_of_Related_Interactions.mean()
# Out:
# 1.1332874413802005

# %%
data.No_of_Related_Interactions.replace(np.nan,1,inplace=True)

# %%
data.Closure_Code.value_counts()
# Out:
# Other                           16469
# Software                        13023
# User error                       3554
# No error - works as designed     3529
# Hardware                         2999
# Data                             2209
# Unknown                          1590
# Operator error                   1539
# User manual not used              765
# Inquiry                           162
# Referred                          158
# Questions                         132
# Kwaliteit van de output            10
# Overig                              1
# Name: Closure_Code, dtype: int64

# %%
data.Closure_Code.replace(np.nan,'Other',inplace=True)

# %%
data.isnull().sum()
# Out:
# CI_Name                           0
# CI_Cat                            0
# CI_Subcat                         0
# WBS                               0
# Incident_ID                       0
# Status                            0
# Impact                            0
# Urgency                           0
# Priority                          0
# number_cnt                        0
# Category                          0
# KB_number                         0
# Alert_Status                      0
# No_of_Reassignments               0
# Open_Time                         0
# Reopen_Time                   44317
# Resolved_Time                  1780
# Close_Time                        0
# Handle_Time_hrs                   1
# Closure_Code                      0
# No_of_Related_Interactions        0
# Related_Interaction               0
# No_of_Related_Incidents       45381
# No_of_Related_Changes         46040
# Related_Change                46040
# dtype: int64

# %%
data.Reopen_Time.isnull().sum()/len(data)*100
# Out:
# 95.10085836909872

# %%
data.Resolved_Time.value_counts()
# Out:
# 2013-10-10 12:53:00    7
# 2013-12-16 09:47:00    6
# 2014-12-02 10:59:00    6
# 2014-03-31 09:20:00    6
# 2013-06-11 05:12:00    6
# 2014-10-03 09:42:00    6
# 2014-01-21 08:29:00    6
# 2014-10-03 09:41:00    6
# 2013-11-20 16:36:00    6
# 2014-03-26 10:24:00    6
# 2014-02-19 12:24:00    5
# 2013-12-20 15:47:00    5
# 2014-01-20 15:42:00    5
# 2013-11-29 12:13:00    5
# 2014-01-13 14:50:00    5
# 2013-10-29 11:34:00    5
# 2013-12-18 09:39:00    5
# 2013-11-18 14:01:00    5
# 2014-01-13 13:33:00    5
# 2014-09-01 15:34:00    5
# 2014-03-19 08:31:00    5
# 2014-01-31 11:58:00    5
# 2013-10-17 15:54:00    5
# 2013-11-18 09:19:00    5
# 2014-02-14 14:47:00    5
# 2014-07-01 13:57:00    5
# 2014-03-13 10:49:00    5
# 2013-05-11 08:34:00    5
# 2013-12-23 14:43:00    5
# 2014-10-03 10:14:00    5
# 2014-08-01 11:15:00    5
# 2013-07-10 12:50:00    5
# 2014-03-31 09:54:00    5
# 2013-12-12 12:09:00    5
# 2013-03-10 15:33:00    5
# 2014-03-18 15:35:00    5
# 2013-10-30 14:48:00    5
# ...

# %%
data.Handle_Time_hrs.value_counts()
# Out:
# 0                 236
# 0:034444444        23
# 0:018333333        22
# 0:021388889        19
# 0:009722222        19
# 0:016666667        19
# 0:029166667        18
# 0:017777778        18
# 0:014722222        17
# 0:037777778        17
# 0:020555556        17
# 0:026388889        17
# 0:013888889        16
# 0:014444444        16
# 0:017222222        16
# 0:020277778        16
# 0:015555556        16
# 0:018611111        16
# 0:025              16
# 0:011666667        16
# 0:05               15
# 0:015833333        15
# 0:021666667        15
# 0:025833333        15
# 0:013611111        15
# 0:026944444        15
# 0:049444444        14
# 0:023611111        14
# 0:01               14
# 0:0075             14
# 0:020833333        14
# 0:014166667        14
# 0:013333333        14
# 0:040277778        13
# 0:013055556        13
# 0:016111111        13
# 0:023055556        13
# 0:011944444        13
# 0:021111111        13
# 0:028055556        13
# 0:036388889        13
# ...

# %%
data.No_of_Related_Incidents.isnull().sum()/len(data)*100
# Out:
# 97.38412017167381

# %%
data.No_of_Related_Changes.isnull().sum()/len(data)*100
# Out:
# 98.79828326180258

# %%
data.Related_Change.isnull().sum()/len(data)*100
# Out:
# 98.79828326180258

# %% [markdown]
# ## labelencod

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46600 entries, 0 to 46605
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   CI_Name                     46600 non-null  object
#  1   CI_Cat                      46600 non-null  object
#  2   CI_Subcat                   46600 non-null  object
#  3   WBS                         46600 non-null  object
#  4   Incident_ID                 46600 non-null  object
#  5   Status                      46600 non-null  object
#  6   Impact                      46600 non-null  int32
#  7   Urgency                     46600 non-null  int32
#  8   Priority                    46600 non-null  int32
#  9   number_cnt                  46600 non-null  float64
#  10  Category                    46600 non-null  object
#  11  KB_number                   46600 non-null  object
#  12  Alert_Status                46600 non-null  object
# ...

# %%
data.describe(include=['object'])
# Out:
#           CI_Name       CI_Cat                 CI_Subcat        WBS  \
# count       46600        46600                     46600      46600
# unique       3019           12                        64        274
# top     SUB000456  application  Server Based Application  WBS000073
# freq         3050        33005                     18919      13340
#
#        Incident_ID  Status  Category  KB_number Alert_Status Handle_Time_hrs  \
# count        46600   46600     46600      46600        46600           46599
# unique       46600       2         4       1824            1           30635
# top      IM0021500  Closed  incident  KM0001106       closed               0
# freq             1   46591     37743       1106        46600             236
#
#        Closure_Code Related_Interaction Related_Change
# count         46600               46600            560
# unique           14               43057            232
# top           Other         #MULTIVALUE      C00003013
# ...

# %%
##coverting categorical features to numerical
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
data.CI_Name=label.fit_transform(data.CI_Name)
data.CI_Cat=label.fit_transform(data.CI_Cat)
data.CI_Subcat=label.fit_transform(data.CI_Subcat)
data.WBS=label.fit_transform(data.WBS)
data.Incident_ID=label.fit_transform(data.Incident_ID)
data.Status=label.fit_transform(data.Status)
data.Category=label.fit_transform(data.Category)
data.KB_number=label.fit_transform(data.KB_number)
data.Alert_Status=label.fit_transform(data.Alert_Status)
data.Closure_Code=label.fit_transform(data.Closure_Code)
data.Related_Interaction=label.fit_transform(data.Related_Interaction)

# %%
plt.figure(figsize=(25, 25))
sns.heatmap(data.corr(), annot=True, fmt= '.1f', cmap="BrBG")
sns.set(font_scale=3.25)
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46600 entries, 0 to 46605
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   CI_Name                     46600 non-null  int32
#  1   CI_Cat                      46600 non-null  int32
#  2   CI_Subcat                   46600 non-null  int32
#  3   WBS                         46600 non-null  int32
#  4   Incident_ID                 46600 non-null  int32
#  5   Status                      46600 non-null  int32
#  6   Impact                      46600 non-null  int32
#  7   Urgency                     46600 non-null  int32
#  8   Priority                    46600 non-null  int32
#  9   number_cnt                  46600 non-null  float64
#  10  Category                    46600 non-null  int32
#  11  KB_number                   46600 non-null  int32
#  12  Alert_Status                46600 non-null  int32
# ...

# %%
## displays the correlated data 
corr_matrix = data.corr()
corr_matrix["Priority"].sort_values(ascending=False)
# Out:
# Priority                      1.000000
# Impact                        0.992441
# Urgency                       0.989999
# Category                      0.474046
# CI_Name                       0.117064
# CI_Subcat                     0.091472
# No_of_Reassignments           0.090126
# KB_number                     0.087655
# WBS                           0.027393
# number_cnt                    0.000388
# No_of_Related_Changes        -0.002834
# Status                       -0.022623
# Related_Interaction          -0.027150
# Incident_ID                  -0.029359
# No_of_Related_Interactions   -0.035360
# CI_Cat                       -0.042488
# Closure_Code                 -0.091127
# No_of_Related_Incidents      -0.173992
# Alert_Status                       NaN
# Name: Priority, dtype: float64

# %%
data.head()
# Out:
#    CI_Name  CI_Cat  CI_Subcat  WBS  Incident_ID  Status  Impact  Urgency  \
# 0     2741      11         57  137            0       0       4        4
# 1     2863       1         57   70            1       0       3        3
# 2      990       1         10   74            2       0       3        3
# 3     2863       1         57   70            3       0       4        4
# 4     2863       1         57   70            4       0       4        4
#
#    Priority  number_cnt  Category  KB_number  Alert_Status  \
# 0         4    0.601292         1        413             0
# 1         3    0.415050         1        456             0
# 2         3    0.517551         3        244             0
# 3         4    0.642927         1        456             0
# 4         4    0.345258         1        456             0
#
#    No_of_Reassignments           Open_Time         Reopen_Time  \
# 0                 26.0 2012-05-02 13:32:00                 NaT
# ...

# %%
X = data.loc[:,['CI_Name','CI_Subcat','WBS','Impact','Urgency','Category','No_of_Reassignments','KB_number','number_cnt']]
y = data.Priority

# %%
X.head()
# Out:
#    CI_Name  CI_Subcat  WBS  Impact  Urgency  Category  No_of_Reassignments  \
# 0     2741         57  137       4        4         1                 26.0
# 1     2863         57   70       3        3         1                 33.0
# 2      990         10   74       3        3         3                  3.0
# 3     2863         57   70       4        4         1                 13.0
# 4     2863         57   70       4        4         1                  2.0
#
#    KB_number  number_cnt
# 0        413    0.601292
# 1        456    0.415050
# 2        244    0.517551
# 3        456    0.642927
# 4        456    0.345258

# %%
y.head()
# Out:
# 0    4
# 1    3
# 2    3
# 3    4
# 4    4
# Name: Priority, dtype: int32

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
# Splitting the data into test and train for calculating accuracy
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=10)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((32620, 9), (13980, 9), (32620,), (13980,))

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32620 entries, 2331 to 17676
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CI_Name              32620 non-null  int32
#  1   CI_Subcat            32620 non-null  int32
#  2   WBS                  32620 non-null  int32
#  3   Impact               32620 non-null  int32
#  4   Urgency              32620 non-null  int32
#  5   Category             32620 non-null  int32
#  6   No_of_Reassignments  32620 non-null  float64
#  7   KB_number            32620 non-null  int32
#  8   number_cnt           32620 non-null  float64
# dtypes: float64(2), int32(7)
# memory usage: 1.6 MB

# %%
X_train.describe()
# Out:
#             CI_Name     CI_Subcat           WBS        Impact       Urgency  \
# count  32620.000000  32620.000000  32620.000000  32620.000000  32620.000000
# mean    2241.270754     41.809595    107.760607      4.186450      4.188994
# std      750.890662     17.010247     69.716908      0.724887      0.724206
# min        0.000000      0.000000      0.000000      1.000000      1.000000
# 25%     2276.000000     42.000000     59.000000      4.000000      4.000000
# 50%     2487.000000     45.000000     73.000000      4.000000      4.000000
# 75%     2725.000000     57.000000    159.000000      5.000000      5.000000
# max     3018.000000     62.000000    273.000000      5.000000      5.000000
#
#            Category  No_of_Reassignments     KB_number    number_cnt
# count  32620.000000         32620.000000  32620.000000  32620.000000
# mean       1.378050             1.134335    885.807020      0.499090
# std        0.783539             2.293398    485.213469      0.288105
# ...

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13980 entries, 19709 to 26312
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CI_Name              13980 non-null  int32
#  1   CI_Subcat            13980 non-null  int32
#  2   WBS                  13980 non-null  int32
#  3   Impact               13980 non-null  int32
#  4   Urgency              13980 non-null  int32
#  5   Category             13980 non-null  int32
#  6   No_of_Reassignments  13980 non-null  float64
#  7   KB_number            13980 non-null  int32
#  8   number_cnt           13980 non-null  float64
# dtypes: float64(2), int32(7)
# memory usage: 709.9 KB

# %%
X_test.describe()
# Out:
#             CI_Name     CI_Subcat           WBS        Impact       Urgency  \
# count  13980.000000  13980.000000  13980.000000  13980.000000  13980.000000
# mean    2234.666953     41.642847    109.020172      4.189914      4.191202
# std      754.784398     17.070784     70.401292      0.725743      0.725602
# min        1.000000      1.000000      1.000000      2.000000      2.000000
# 25%     2269.000000     42.000000     59.000000      4.000000      4.000000
# 50%     2487.000000     45.000000     73.000000      4.000000      4.000000
# 75%     2725.000000     57.000000    166.000000      5.000000      5.000000
# max     3016.000000     63.000000    273.000000      5.000000      5.000000
#
#            Category  No_of_Reassignments     KB_number    number_cnt
# count  13980.000000          13980.00000  13980.000000  13980.000000
# mean       1.382546              1.12618    884.099142      0.501073
# std        0.786999              2.21402    481.118922      0.289850
# ...

# %% [markdown]
# ## scaling

# %%
from scipy.stats import skew
from scipy.stats import kurtosis

# %%
for col in X_test:
    print(col)
    print(skew(data[col]))
    
    plt.figure()
    sns.distplot(data[col])
    plt.show()
# Out:
# CI_Name
# -1.57817195402251
# CI_Subcat
# -1.1660791536053108
# WBS
# 0.8329426249340296
# Impact
# -0.5382898189225968
# Urgency
# -0.5476339893096761
# Category
# 1.5799763131313527
# No_of_Reassignments
# 4.827085206880001
# KB_number
# 0.06518098271192717
# number_cnt
# 0.002511773796967424

# %%
for col in X_train:
    print(col)
    print(kurtosis(data[col]))
    
    plt.figure()
    sns.distplot(data[col])
    plt.show()
# Out:
# CI_Name
# 1.364962902621138
# CI_Subcat
# 0.06272417752763548
# WBS
# -0.6619754648329121
# Impact
# -0.16048561121683624
# Urgency
# -0.12550342760052802
# Category
# 0.5019833952004311
# No_of_Reassignments
# 41.83434877086769
# KB_number
# -0.970258919011747
# number_cnt
# -1.2004535596825845

# %%
from sklearn.preprocessing import StandardScaler

from sklearn.preprocessing import MinMaxScaler

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.2833069 ,  0.18756069, -0.69941935, ..., -0.49461631,
#          0.36725219,  0.1767648 ],
#        [ 0.58961451,  0.18756069, -0.44122838, ..., -0.49461631,
#         -1.47732504,  0.70958092],
#        [ 0.62290882,  0.89302865, -0.69941935, ...,  1.68558802,
#          0.56510629,  0.74748548],
#        ...,
#        [ 0.41382058,  0.18756069,  1.86814638, ...,  0.37746542,
#         -0.17684657,  0.44181823],
#        [-1.5865013 , -1.87005419, -0.52729204, ...,  1.24954715,
#         -1.04245823, -0.63445185],
#        [ 0.12615778,  0.18756069, -1.20145734, ..., -0.49461631,
#         -1.59273993,  1.68680155]])

# %% [markdown]
# ## Models

# %%
# Training the model
from sklearn.svm import SVC
rbf_svc = SVC(kernel='rbf',C=10,gamma=0.1).fit(X_train,y_train)

# %%
y_predict_svm = rbf_svc.predict(X_test)

# %%
# Finding accuracy, precision, recall and confusion matrix
print(accuracy_score(y_test,y_predict_svm))
print(classification_report(y_test,y_predict_svm))
# Out:
# 0.999856938483548
#               precision    recall  f1-score   support
#
#            2       1.00      0.99      0.99       201
#            3       1.00      1.00      1.00      2040
#            4       1.00      1.00      1.00      6753
#            5       1.00      1.00      1.00      4986
#
#     accuracy                           1.00     13980
#    macro avg       1.00      1.00      1.00     13980
# weighted avg       1.00      1.00      1.00     13980

# %%
confusion_matrix(y_test,y_predict_svm)
# Out:
# array([[ 199,    2,    0,    0],
#        [   0, 2040,    0,    0],
#        [   0,    0, 6753,    0],
#        [   0,    0,    0, 4986]], dtype=int64)

# %%
# Training the model
from sklearn.tree import DecisionTreeClassifier
model_dtree=DecisionTreeClassifier()
model_dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Predicting the model
y_predict_dtree = model_dtree.predict(X_test)

# %%
# Finding accuracy, precision, recall and confusion matrix
print(accuracy_score(y_test,y_predict_dtree))
print(classification_report(y_test,y_predict_dtree))
# Out:
# 0.9999284692417739
#               precision    recall  f1-score   support
#
#            2       1.00      1.00      1.00       201
#            3       1.00      1.00      1.00      2040
#            4       1.00      1.00      1.00      6753
#            5       1.00      1.00      1.00      4986
#
#     accuracy                           1.00     13980
#    macro avg       1.00      1.00      1.00     13980
# weighted avg       1.00      1.00      1.00     13980

# %%
confusion_matrix(y_test,y_predict_dtree)
# Out:
# array([[ 201,    0,    0,    0],
#        [   0, 2039,    1,    0],
#        [   0,    0, 6753,    0],
#        [   0,    0,    0, 4986]], dtype=int64)
